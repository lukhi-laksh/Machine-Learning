# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.image as mpimg

# %% [markdown]
# # SVC VS SVR

# %%
plt.figure(figsize=(6, 5))
img = mpimg.imread('Image/SVC and SVR.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# In SVC we are Saperate Two Category
# We focus on all data stay in outside of the suport vecotor line
# In SVR we are focus on all data stay in inside the suport vector line
# in SVC we find longest distant prediction line
# in SVR we find shortest distant prediction line in where all data are comes
# in SVC that category comes inside Prediction line is called missclassifiar
# in SVR that category comes outside of prediction line called missclassifiar

# %%
df = pd.read_csv('../Dataset/placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x = 'cgpa', y = 'package', data=df)
plt.show()

# %%
x = df[['cgpa']]
y = df['package']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVR
sv = SVR(kernel='linear')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 77.06668029575103

# %%
sns.scatterplot(x='cgpa', y='package', data=df)
plt.plot(df['cgpa'], sv.predict(x), color='r')
plt.show()

# %%
from sklearn.svm import SVR
sv = SVR(kernel='rbf')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 75.94945442913415

# %%
sns.scatterplot(x='cgpa', y='package', data=df)
plt.plot(df['cgpa'], sv.predict(x), color='r')
plt.show()

# %%
from sklearn.svm import SVR
sv = SVR(kernel='sigmoid')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# -0.12751631607434977

# %%
sns.scatterplot(x='cgpa', y='package', data=df)
plt.plot(df['cgpa'], sv.predict(x), color='r')
plt.show()

# %%
from sklearn.svm import SVR
sv = SVR(kernel='poly', degree=3)
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 72.30726378194225

# %%
sns.scatterplot(x='cgpa', y='package', data=df)
plt.plot(df['cgpa'], sv.predict(x), color='r')
plt.show()

# %% [markdown]
# #### So, Support Vector Classification and Regression both are support same Kernal and formula
