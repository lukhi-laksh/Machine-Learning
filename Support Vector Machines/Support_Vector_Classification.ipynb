# %% [markdown]
# # **SVM in Classification**

# %% [markdown]
# ## SVM is one of them most popular Supervised Learning algorithms, which is used for Classification as well as Regression Problems.

# %% [markdown]
# ### **Hard Margin:** The algorithm Aims to find a hyperplane that perfectly separates the data into two classes without any misclassifications.
#
# ### **Soft Margin:** The algorithm allows for some misclassifications to find a hyperplane that generalizes better to unseen data and is more robust to outliers.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.image as mpimg

# %%
plt.figure(figsize=(6, 5))
img = mpimg.imread('Image/Suport Vector Line.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# we can show there is Two Suport Vectore points where line is draw
# That two dots is Called Suport Vectors
# We find best Lines that saperate our Categorys
# and that that two best line using we find average line or devide by 2 line 
# we need to draw that two line in maximum margin have and there is no dotes between that two lines
# that first line --- avg line --- second line between there is must be not any dots come
# if that dots comes in in our that tree line than that dot's called Missclassification that give us wrong prediction
# if there is dots in our line that called Hard Margin 
# if there is no dots in our line that called Soft Margin
# Main motive of Classification is choose perfect two support vector that gave max Distance

# %%
# what is the difference between linear and non linear
# if our data is able to saparate in linear than it's can do but
# if our darta is not able to do saperate in two parts i mean outside other and inside other category
# then also SVM can saperate them

# %%
plt.figure(figsize=(6, 5))
img = mpimg.imread('Image/types.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 1. Linear SVM

# %%
plt.figure(figsize=(6, 5))
img = mpimg.imread('Image/Linear.jpeg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 2. Non-linear SVM

# %%
# if our data is not able to saperate with Linear line then we need to use kernal
# kernal modify data and find prediction line

# %% [markdown]
# ## Types of SVMs
# ### 1. **Simple SVM:** Typically used for linear regression and classification problems.
# ### 2. **Kernal SVM:** Has more flexibility for non-linear data because you can add more features to fit a hyperplane istead of a two-dimensional space.

# %% [markdown]
# ## **Kernal Function**

# %% [markdown]
# kernel functions play a crucial role in transforming input data into a higher-dimensional space.
#
# The primary purpose of kernel functions is to allow SVMs to handle non-linearly separable data by implicitly mapping the input data into a higher-dimensional feature space where linear separation may be more feasible.
#
# This transformation is done without explicitly calculating the coordinates points in that higher-dimensional space.

# %% [markdown]
# ⭐ 1. Linear Kernel
# Simple Definition
#
# Linear means a straight-line relation like
# y = mx + c
#
# In SVM kernel: measuring similarity using simple dot product.
#
# LaTeX
# $$
# K(x_i, x_j) = x_i^T x_j + b
# $$
#
# ⭐ 2. Polynomial Kernel
# Simple Definition
#
# Polynomial means
# m·x + c,
# (m·x + c)^2,
# (m·x + c)^3, etc.
#
# It allows curved boundaries (2nd degree, 3rd degree…).
#
# LaTeX
# $$
# K(x_i, x_j) = (\gamma \, x_i^T x_j + b)^{\,N}
# $$
#
# ⭐ 3. Gaussian RBF Kernel (Radial Basis Function)
# Simple Definition
#
# Measures similarity based on distance.
#
# If two points are close → high value
#
# If far → almost 0
#
# Creates circular (radial) decision boundaries.
#
# LaTeX
# $$
# K(x_i, x_j) = \exp\left(-\gamma \, \|x_i - x_j\|^{2}\right)
# $$
#
# ⭐ 4. Sigmoid Kernel (Complete Version)
# Simple Definition
#
# Works like a neural network activation function
# tanh(m·x + c)
#
# Creates smooth S-shaped decision boundaries.
#
# LaTeX
# $$
# K(x_i, x_j) = \tanh(\alpha \, x_i^T x_j + c)
# $$

# %% [markdown]
# ## Kernel Functions
#
# ### 1. Linear Kernel
# $$
# K(x_i, x_j) = x_i^T x_j + b
# $$
# Linear kernel means straight-line decision boundary (like \(y = mx + c\)).
#
# ---
#
# ### 2. Polynomial Kernel
# $$
# K(x_i, x_j) = (\gamma \, x_i^T x_j + b)^{\,N}
# $$
# Polynomial means curved boundaries (square, cube, etc).
#
# ---
#
# ### 3. Gaussian RBF Kernel
# $$
# K(x_i, x_j) = \exp\left(-\gamma \, \|x_i - x_j\|^{2}\right)
# $$
# RBF measures similarity based on distance (close = high similarity).
#
# ---
#
# ### 4. Sigmoid Kernel
# $$
# K(x_i, x_j) = \tanh(\alpha \, x_i^T x_j + c)
# $$
# Sigmoid acts like a neural network activation function.

# %%
# Kernal Can change 1d array to 2d array x to x1 and x2
# so using kernal we just change our Data and try to predict
# We use all model which gives us most Accureccy we are use that kernal and predict

# %%
df = pd.read_csv('../Dataset/placement_.csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x = 'cgpa', y = 'resume_score', data=df, hue='placed')
plt.show()

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1:]
x.head()
# Out:
#    cgpa  resume_score
# 0  8.14          6.52
# 1  6.17          5.17
# 2  8.27          8.86
# 3  6.88          7.27
# 4  7.52          7.30

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC
sv = SVC(kernel='linear')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='poly')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='rbf')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='sigmoid')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)
# Out:
# 0.5

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %% [markdown]
# ### What if our data is not able to Linearly separable

# %%
df = pd.read_csv('../Dataset/nonlinear_data_circles.csv')
df.head()
# Out:
#          x1        x2  label
# 0  0.160594  0.482602      1
# 1  1.198440 -0.542104      0
# 2 -0.618907  0.728517      0
# 3  1.070839 -0.340617      0
# 4  0.843196 -0.502865      0

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x = 'x1', y = 'x2', data=df, hue='label')
plt.show()

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1:]
x.head()
# Out:
#          x1        x2
# 0  0.160594  0.482602
# 1  1.198440 -0.542104
# 2 -0.618907  0.728517
# 3  1.070839 -0.340617
# 4  0.843196 -0.502865

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC
sv = SVC(kernel='linear')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 59.45

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='poly')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 62.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='rbf')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 99.85000000000001

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()

# %%
from sklearn.svm import SVC
sv = SVC(kernel='sigmoid')
sv.fit(x_train, y_train)
sv.score(x_test, y_test)*100
# Out:
# 50.2

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X = x.to_numpy(), y = y.to_numpy().flatten(), clf=sv)
plt.show()
